# %%
import pandas as pd
import bokeh
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07dc10ef-ac1c-41cf-b1c1-388f2e720f2d">Loading BokehJS ...</span>
#     </div>

# %%
line1 = [] # <20
line2 = [] # 21~44
line3 = [] # 45~64
line4 = [] # >65
total = []
for i in range(2000,2017):
    df = pd.read_csv(r'data\age\%d.xls'%(i),sep = '\t',header = None)
    df = df.iloc[1:,:]
    df.columns = ['age', 'number','nan']
    num = df['number']
    line1.append(sum(map(int,num[0:4])))
    line2.append(sum(map(int,num[4:7])))
    line3.append(sum(map(int,num[7:9])))
    line4.append(sum(map(int,num[9:11])))
    total.append(int(num[13]))
tt = [i/3 for i in total]

# %%
from bokeh.transform import factor_cmap
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure

years = [str(i) for i in list(range(2000,2017))]
ages = ['<20', '20~45', '45~65','>65']

data = {'years' : years,
        '<20'   : line1,
        '20~44'   : line2,
        '45~64'   : line3,
       '>65': line4  }

# this creates [ ("2015", "<20"), ("2015", "20~45"), ("2015", "45~65), ("2015", ">65"), ... ]
x = [ (year, age) for year in years for age in ages ]
counts = sum(zip(data['<20'], data['20~44'], data['45~64'], data['>65']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), plot_height=250,plot_width = 1000, title="Persons killed, by age")

p.vbar(x='x', top='counts', width=0.9, source=source,line_color="white",
       # use the palette to colormap based on the the x[1:2] values
       fill_color=factor_cmap('x', palette=['#225ea8', '#41b6c4', '#a1dab4', '#35B778'], factors=ages, start=1, end=2))


p.line(x=years, y=tt, color="red", line_width=1)
p.circle(x=years, y=tt, line_color="red", fill_color="white", size=10)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
years
# Out:
#   <div class="bk-root" id="1470d1a5-a00e-49e8-a4cb-6f0a0c2780b2"></div>
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

years = [str(i) for i in list(range(2000,2017))]
ages = ['<20', '20~45', '45~65','>65']

data = {'years' : years,
        '<20'   : line1,
        '21~44'   : line2,
        '45~64'   : line3,
       '>65': line4  }

source = ColumnDataSource(data=data)

p = figure(x_range=years, plot_height=350,plot_width = 800, title="Persons killed, by age (2000~2016)",
           toolbar_location=None, tools="")

p.vbar(x=dodge('years', -0.3, range=p.x_range), top='<20', width=0.2, source=source,
       color="#225ea8", legend=value('<20'))

p.vbar(x=dodge('years',  -0.1,  range=p.x_range), top='21~44', width=0.2, source=source,
       color="#718dbf", legend=value('21~44'))

p.vbar(x=dodge('years',  0.1, range=p.x_range), top='45~64', width=0.2, source=source,
       color="#e84d60", legend=value('45~64'))

p.vbar(x=dodge('years',  0.3, range=p.x_range), top='>65', width=0.2, source=source,
       color="#41b6c4", legend=value('>65'))

p.line(x=years, y=tt, legend = '"total"',line_dash=[4, 4], color="black", line_width=1)
p.circle(x=years, y=tt, line_color="black",legend = '"total"', fill_color="white", size=5)

p.xaxis.axis_label = 'years'
p.yaxis.axis_label = 'number'

p.y_range.end = 22000
p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div class="bk-root" id="fe58bba5-50ad-432a-b787-26783caff1e6"></div>

# %%
line1 = [] # <20
line2 = [] # 21~44
line3 = [] # 45~64
line4 = [] # >65
total = []
for i in range(1994,2017):
    df = pd.read_csv(r'data\age\%d.xls'%(i),sep = '\t',header = None)
    df = df.iloc[1:,:]
    df.columns = ['age', 'number','nan']
    num = df['number']
    line1.append(sum(map(int,num[0:4])))
    line2.append(sum(map(int,num[4:7])))
    line3.append(sum(map(int,num[7:9])))
    line4.append(sum(map(int,num[9:11])))
    total.append(int(num[13]))
tt = [i/3 for i in total]


from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

years = [str(i) for i in list(range(1994,2017))]
ages = ['<20', '20~45', '45~65','>65']

data = {'years' : years,
        '<20'   : line1,
        '21~44'   : line2,
        '45~64'   : line3,
       '>65': line4  }

source = ColumnDataSource(data=data)

p = figure(plot_width=800, plot_height=400, title="person killed, by age (1994~2016)")

p.line(x=years, y=line1, legend = '<20', color="orange", line_width=1)
p.circle(x=years, y=line1, line_color="orange",legend = '<20', fill_color="orange", size=5)

p.line(x=years, y=line2, legend = '21~44', color="blue", line_width=1)
p.circle(x=years, y=line2, line_color="blue",legend = '21~44', fill_color="blue", size=5)

p.line(x=years, y=line3, legend = '45~64', color="green", line_width=1)
p.circle(x=years, y=line3, line_color="green",legend = '45~64', fill_color="green", size=5)

p.line(x=years, y=line4, legend = '>65', color="red", line_width=1)
p.circle(x=years, y=line4, line_color="red",legend = '>65', fill_color="red", size=5)

p.y_range.start = 0
p.y_range.end = 25000
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

p.xaxis.axis_label = 'years'
p.yaxis.axis_label = 'number'

show(p)
# Out:
#   <div class="bk-root" id="68ba0136-37a6-4e4b-b689-dcd252228f36"></div>

# %%
from math import pi
from bokeh.palettes import Category20c
from bokeh.transform import cumsum

df = pd.read_csv(r'data\age\2016.xls',sep = '\t',header = None)
df = df.iloc[1:,:]
df.columns = ['age', 'number','nan']
num = df['number']
num = list(map(int,num[1:11]))
age = df['age']
age = list(age[1:11])
d = dict(zip(age,num))

data = pd.Series(d).reset_index(name='number').rename(columns={'index':'age'})
data['color'] = Category20c[len(d)]
# represent each value as an angle = value / total * 2pi
data['angle'] = data['number']/data['number'].sum() * 2*pi

p = figure(plot_height=350, title="Person killed, by age, 2016", toolbar_location=None,
           tools="hover", tooltips="@age: @number")

p.wedge(x=0, y=1, radius=0.4, 
        # use cumsum to cumulatively sum the values for start and end angles
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend='age', source=data)

p.axis.axis_label= None
p.axis.visible= False
p.grid.grid_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="7b1fbcf4-21a9-495c-912b-4cc3b6b6eb8a"></div>

# %%
from math import pi
from bokeh.palettes import Category20
from bokeh.transform import cumsum
from bokeh.models.annotations import Label
import math

df = pd.read_csv(r'data\age\2016.xls',sep = '\t',header = None)
df = df.iloc[1:,:]
df.columns = ['age', 'number','nan']
num = df['number']
a1 = sum(map(int,num[0:4]))
a2 = sum(map(int,num[4:7]))
a3 = sum(map(int,num[7:9]))
a4 = sum(map(int,num[9:11]))
age = ['<20', '20~45', '45~65','>65']
num = [a1,a2,a3,a4]
num = [i*100/sum(num) for i in num]
d = dict(zip(age,num))

data = pd.Series(d).reset_index(name='number').rename(columns={'index':'age'})
data['color'] = ['orange','blue','green','red']
# represent each value as an angle = value / total * 2pi
data['angle'] = data['number']/data['number'].sum() * 2*pi

p = figure(plot_height=350, title="Person killed, by age, 2016", toolbar_location=None,
           tools="hover", tooltips="@age: @number")

p.wedge(x=0, y=1, radius=0.4, 
        # use cumsum to cumulatively sum the values for start and end angles
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend='age', source=data)

label1 = Label(x=0.15, y=1.2, x_offset=15, text="%d%%"%(num[0]), text_baseline="middle",text_color='white')
p.add_layout(label1)
label2 = Label(x=-0.2, y=1.35, x_offset=15, text="%d%%"%(math.ceil(num[1])), text_baseline="middle",text_color='white')
p.add_layout(label2)
label3 = Label(x=-0.2, y=0.62, x_offset=15, text="%d%%"%(num[2]), text_baseline="middle",text_color='white')
p.add_layout(label3)
label4 = Label(x=0.1, y=0.75, x_offset=15, text="%d%%"%(num[3]), text_baseline="middle",text_color='white')
p.add_layout(label4)

p.axis.axis_label= None
p.axis.visible= False
p.grid.grid_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="995f9a01-ad76-4bf8-a385-09a68b68557c"></div>

# %%
df = pd.read_csv(r'data\speed\2009.xls',sep = '\t',header = None)
df
# Out:
#                      0         1        2        3         4        5  \
# 0                  NaN  Land Use      NaN      NaN       NaN      NaN
# 1                  NaN     Rural      NaN    Urban       NaN  Unknown
# 2          Speed Limit    Number  Percent  Number1  Percent1  Number2
# 3       30 mph or less       891     25.7     2552      73.6       26
# 4         35 or 40 mph      1935     32.8     3953      67.1        4
# 5         45 or 50 mph      3180     48.2     3412      51.7       10
# 6               55 mph      7995     81.2     1854      18.8        2
# 7     60 mph or higher      4877     68.8     2200      31.1        8
# 8   No Statutory Limit        92     75.4       30      24.6        0
# 9              Unknown       353     41.0      500      58.0        9
# 10               Total     19323     57.0    14501      42.8       59
#
#            6        7         8   9
# 0        NaN      NaN       NaN NaN
# 1        NaN    Total       NaN NaN
# ...

# %%
df = df.iloc[3:,:]
df.columns = ['speed', 'rural1','rural2','urban1','urban2','uk1','uk2','total','nan','nan']
df
# Out:
#                  speed rural1 rural2 urban1 urban2 uk1  uk2  total    nan  nan
# 3       30 mph or less    891   25.7   2552   73.6  26  0.7   3469  100.0  NaN
# 4         35 or 40 mph   1935   32.8   3953   67.1   4  0.1   5892  100.0  NaN
# 5         45 or 50 mph   3180   48.2   3412   51.7  10  0.2   6602  100.0  NaN
# 6               55 mph   7995   81.2   1854   18.8   2  0.0   9851  100.0  NaN
# 7     60 mph or higher   4877   68.8   2200   31.1   8  0.1   7085  100.0  NaN
# 8   No Statutory Limit     92   75.4     30   24.6   0  0.0    122  100.0  NaN
# 9              Unknown    353   41.0    500   58.0   9  1.0    862  100.0  NaN
# 10               Total  19323   57.0  14501   42.8  59  0.2  33883  100.0  NaN

# %%
speed = list(df['speed'][:5])
rural = list(df['rural1'][:5])
urban = list(df['urban1'][:5])

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

data = {'speed' : speed,
        'rural': rural,
       'urban': urban}

source = ColumnDataSource(data=data)

p = figure(x_range=speed, plot_height=350, title="Persons killed, by place",
           toolbar_location=None, tools="")

p.vbar(x=dodge('speed', -0.12, range=p.x_range), top='rural', width=0.2, source=source,
       color="#41b6c4", legend=value('rural'))

p.vbar(x=dodge('speed',  0.12,  range=p.x_range), top='urban', width=0.2, source=source,
       color="#35B778", legend=value('urban'))

p.xaxis.axis_label = 'Speed Limit'
p.yaxis.axis_label = 'number'

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div class="bk-root" id="b4fcecea-be85-42c7-840d-a7c2b7fe5925"></div>

# %%
df = pd.read_csv(r'data\age and time of day.txt',sep = '\t',header = None)
df = df.iloc[1:,:]
head = [str(i) for i in range(0,103)]
head = ['time'] + head + ['nr','uk','total','nan']
df.columns = head
import numpy as np
interval1 = np.zeros(24)#<18
interval2 = np.zeros(24)#19~30
interval3 = np.zeros(24)#31~45
interval4 = np.zeros(24)#46~60
interval5 = np.zeros(24)# >60
for i in range(0,20):
    interval1 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(21,44):
    interval2 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(45,65):
    interval3 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(65,102):
    interval4 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(61,102):
    interval5 += np.array(list(map(int,df['%d'%(i)][0:24])))
total = list(map(int,df['total'][0:24]))    
times = list(range(0,24))

p = figure(plot_width=800, plot_height=400, title="crushes, by age and time of the day")

p.line(x=times, y=interval1, legend = '<20', color="orange", line_width=1)
p.circle(x=times, y=list(interval1), line_color="orange",legend = '<20', fill_color="orange", size=5)

p.line(x=times, y=interval2, legend = '21~44', color="blue", line_width=1)
p.circle(x=times, y=interval2, line_color="blue",legend = '21~44', fill_color="blue", size=5)

p.line(x=times, y=interval3, legend = '45~64', color="green", line_width=1)
p.circle(x=times, y=interval3, line_color="green",legend = '45~64', fill_color="green", size=5)

p.line(x=times, y=interval4, legend = '>65', color="red", line_width=1)
p.circle(x=times, y=interval4, line_color="red",legend = '>65', fill_color="red", size=5)

p.line(x=times, y=total, legend = 'total', color="black", line_width=1)
p.circle(x=times, y=total, line_color="black",legend = 'total', fill_color="black", size=5)


p.legend.location = "top_left"
p.legend.orientation = "horizontal"

p.xaxis.axis_label = 'time of a day'
p.yaxis.axis_label = 'number'

show(p)
# Out:
#   <div class="bk-root" id="8325d987-5088-4b5d-8e4b-22d3338ba295"></div>

# %%
df = pd.read_csv(r'data\age and time of day.txt',sep = '\t',header = None)
df = df.iloc[1:,:]
head = [str(i) for i in range(0,103)]
head = ['time'] + head + ['nr','uk','total','nan']
df.columns = head
import numpy as np
interval1 = np.zeros(24)#<18
interval2 = np.zeros(24)#19~30
interval3 = np.zeros(24)#31~45
interval4 = np.zeros(24)#46~60
interval5 = np.zeros(24)# >60
for i in range(0,18):
    interval1 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(19,30):
    interval2 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(31,45):
    interval3 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(46,60):
    interval4 += np.array(list(map(int,df['%d'%(i)][0:24])))
for i in range(61,102):
    interval5 += np.array(list(map(int,df['%d'%(i)][0:24])))
total = list(map(int,df['total'][0:24]))    
times = list(range(0,24))

p = figure(plot_width=800, plot_height=400, title="crushes, by age and time of the day (2016)")

p.line(x=times, y=interval1, legend = '<18', color="orange", line_width=1)
p.circle(x=times, y=list(interval1), line_color="orange",legend = '<18', fill_color="orange", size=5)

p.line(x=times, y=interval2, legend = '19~30', color="blue", line_width=1)
p.circle(x=times, y=interval2, line_color="blue",legend = '19~30', fill_color="blue", size=5)

p.line(x=times, y=interval3, legend = '31~45', color="green", line_width=1)
p.circle(x=times, y=interval3, line_color="green",legend = '31~45', fill_color="green", size=5)

p.line(x=times, y=interval4, legend = '45~60', color="red", line_width=1)
p.circle(x=times, y=interval4, line_color="red",legend = '45~60', fill_color="red", size=5)

p.line(x=times, y=interval5, legend = '>60', color="black", line_width=1)
p.circle(x=times, y=interval5, line_color="black",legend = '>60', fill_color="black", size=5)

p.y_range.end = 1500
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

p.xaxis.axis_label = 'times'
p.yaxis.axis_label = 'number'

show(p)
# Out:
#   <div class="bk-root" id="22958bd5-e343-495a-b281-bcb116814c6a"></div>
